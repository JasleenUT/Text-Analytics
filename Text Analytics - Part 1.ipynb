# %%
# An example tweet
tweet='We have some delightful new food in the cafeteria. Awesome!!!'

# %%
tweet
# Out:
# 'We have some delightful new food in the cafeteria. Awesome!!!'

# %%
# A list of words having positive connotation
positive_words=['awesome','good','nice','super','fun']

# %%
# To add a word to the existing list
positive_words.append('delightful')

# %%
positive_words
# Out:
# ['awesome', 'good', 'nice', 'super', 'fun', 'delightful']

# %%
# create a list of negative words
negative_words=['awful','lame','horrible','bad']

# %%
# To combine two lists
emotional_words=negative_words+positive_words

# %%
emotional_words
# Out:
# ['awful',
#  'lame',
#  'horrible',
#  'bad',
#  'awesome',
#  'good',
#  'nice',
#  'super',
#  'fun',
#  'delightful']

# %%
# Since our unit of analysis is the word and not sentence, we can split the string
words= tweet.split(' ')
print(words)
# Out:
# ['We', 'have', 'some', 'delightful', 'new', 'food', 'in', 'the', 'cafeteria.', 'Awesome!!!']

# %%
# To see the number of words in the sentence
len(words)
# Out:
# 10

# %%
# Loop to print the list 'words'
for word in words:
    print(word)
# Out:
# We
# have
# some
# delightful
# new
# food
# in
# the
# cafeteria.
# Awesome!!!

# %%
# See if any of the words in the positive list is present in our tweet
for word in words:
    if word in positive_words:
        print(word)
# Out:
# delightful

# %%
# See if any of the words in the negative list is present in our tweet
for word in words:
    if word in negative_words:
        print(word)

# %%
# see if the words are not present in the list
for word in words:
    if not word in positive_words:
        print(word)
# Out:
# We
# have
# some
# new
# food
# in
# the
# cafeteria.
# Awesome!!!

# %%
# To append in print statement
for word in words:
    if word in positive_words:
        print(word + ' is a word with positive connotation')
# Out:
# delightful is a word with positive connotation

# %%
# PREPROCESSING THE DATA
# 1. converting to lowercase
# 2. stripping punctuation
# 3. stemming the words to find the root of the world (e.g. “running” and “runs” both get reduced to “run”)
#    and removing little words like “the”, “and”, or “if”, which are known as stop words

# %%
# 1. Converting to lowercase
tweet.lower()
# Out:
# 'we have some delightful new food in the cafeteria. awesome!!!'

# %%
# You cannot convert list to lowercase
words.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-08ebf87f1254> in <module>()
#       1 # You cannot convert list to lowercase
# ----> 2 words.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
# For loop can be used to convert each word in the list to lowercase
for word in words:
    print(word.lower())
# Out:
# we
# have
# some
# delightful
# new
# food
# in
# the
# cafeteria.
# awesome!!!

# %%
# To compare the lower case words
for word in words:
    if word.lower() in positive_words:
        print(word.lower() + ' is a positive word')
# Out:
# delightful is a positive word

# %%
# it is still not recognizing awesome, remove the punctuation 
tweet.replace('!','')
# Out:
# 'We have some delightful new food in the cafeteria. Awesome'

# %%
# More than one string operation can be included in the same statement
tweet_processed=tweet.replace('!','').replace('.','')
tweet_processed
# Out:
# 'We have some delightful new food in the cafeteria Awesome'

# %%
#convert to lowercase and split
tweet_processed = tweet_processed.lower()
words = tweet_processed.split(' ')
words
# Out:
# ['we',
#  'have',
#  'some',
#  'delightful',
#  'new',
#  'food',
#  'in',
#  'the',
#  'cafeteria',
#  'awesome']

# %%
# Pyhon has built in all punctuation 
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# The best way to remove punctuation is the parse the string and look for all punctuations and replace them
tweet
# Out:
# 'We have some delightful new food in the cafeteria. Awesome!!!'

# %%
tweet_processed1 = tweet.lower()
for p in punctuation:
    tweet_processed1=tweet_processed1.replace(p,'')
tweet_processed1
# Out:
# 'we have some delightful new food in the cafeteria awesome'

# %%
# Now let's see the positive words
for word in words:
    if word in positive_words:
        print(word + ' is a positive word')
# Out:
# delightful is a positive word
# awesome is a positive word

# %%
# Wilson et al. list combines all the positive and negative words so that you don't have to make the lists manually
# Import the module that python needs to communicate with the internet
import urllib.request

# %%
# Store the url having positive words in a variable
url = 'http://www.unc.edu/~ncaren/haphazard/positive.txt'

# %%
# To download and save the file on your local machine (it increases processing speed)
filename = 'file1.txt'
urllib.request.urlretrieve(url,file1)
# Out:
# ('positive.txt', <http.client.HTTPMessage at 0x10bbbc080>)

# %%
# If you want to get 3 files, positive, negative and obama tweets
files = ['positive.txt','negative.txt','obama_tweets.txt']
path = 'http://www.unc.edu/~ncaren/haphazard/'
for filename in files:
    urllib.request.urlretrieve(path+filename,filename)

# %%
# To open the file 
tweets = open('obama_tweets.txt').read()

# %%
tweets
# Out:
# 'Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.\nIn his teen years, Obama has been known to use marijuana and cocaine.\nIPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E\nRT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...\nRT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW\nVideo shows federal officials joking about cost of lavish conference http://t.co/2i4SmoPM #obama #crime #p2 #news #tcot #teaparty\none Chicago kid who says "Obama is my man" tells Jesse Watters that the gun violence in Chicago is like "World War 17"\nRT @ohgirlphrase: American kid "You\'re from the UK? Ohhh cool, So do you have tea with the Queen?". British kid: "Do you like, go to Mcdonalds with Obama?\nA valid explanat
# ...

# %%
# There is a new line character after every tweet. So we can split it at the new line character
tweets_list = tweets.split('\n')

# %%
tweets_list
# Out:
# ['Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.',
#  'In his teen years, Obama has been known to use marijuana and cocaine.',
#  'IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E',
#  'RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...',
#  'RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW',
#  'Video shows federal officials joking about cost of lavish conference http://t.co/2i4SmoPM #obama #crime #p2 #news #tcot #teaparty',
#  'one Chicago kid who says "Obama is my man" tells Jesse Watters that the gun violence in Chicago is like "World War 17"',
# ...

# %%
# Check the number of items in the list
len(tweets_list)
# Out:
# 1381

# %%
# To print only first few tweets
for tweet in tweets_list[0:5]:
    print(tweet)
# Out:
# Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.
# In his teen years, Obama has been known to use marijuana and cocaine.
# IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E
# RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...
# RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW

# %%
# To print only the second tweet
for tweet in tweets_list[1:2]:
    print(tweet)
# Out:
# In his teen years, Obama has been known to use marijuana and cocaine.

# %%
# Let's see the positive sentiment list
pos_words = open('positive.txt').read()

# %%
positive_words = pos_words.split('\n')

# %%
print(positive_words[:10])
# Out:
# ['abidance', 'abidance', 'abilities', 'ability', 'able', 'above', 'above-average', 'abundant', 'abundance', 'acceptance']

# %%
tweets_list
# Out:
# ['Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.',
#  'In his teen years, Obama has been known to use marijuana and cocaine.',
#  'IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E',
#  'RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...',
#  'RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW',
#  'Video shows federal officials joking about cost of lavish conference http://t.co/2i4SmoPM #obama #crime #p2 #news #tcot #teaparty',
#  'one Chicago kid who says "Obama is my man" tells Jesse Watters that the gun violence in Chicago is like "World War 17"',
# ...

# %%
#PREPROCESSING ON THE ENTIRE LIST OF TWEETS
for tweet in tweets_list:
    tweet_processed = tweet.lower()
    for p in punctuation:
        tweet_processed = tweet_processed.replace(p,'')
        words = tweet_processed.split(' ')
    for word in words:
        if word in positive_words:
            print(word)
# Out:
# nice
#
# modern
#
# lavish
# valid
#
#
# advantage
#
#
# dignity
# sense
# will
#
# advantage
#
# significant
#
#
#
# love
#
# funny
#
# good
# support
# reason
# proud
#
# love
#
# just
#
# glad
# will
# white
# just
# easy
# even
# supreme
#
# restraint
# grand
# interest
# will
# defense
#
# right
#
#
# sure
# handsome
# triumph
# novel
# entertaining
#
#
# might
# well
#
# just
# smart
#
# attractive
# free
#
# will
# able
# respect
# passionate
#
# great
# honest
# loyal
# friends
# smart
# just
# rich
#
#
#
# just
# hot
# love
# even
#
# will
# civil
# interest
# will
# fun
# will
# fun
# agreement
# nice
# support
#
# moving
# modern
#
# fun
#
#
#
# open
# praising
# boost
# white
# agreement
#
#
# important
#
#
# respect
#
# will
# effective
# important
#
# strong
# agreement
#
# important
#
#
#
#
# will
# fun
# will
# fun
# well
# good
# fun
#
#
# right
# supreme
# praising
# endorsement
# able
#
#
# sweet
#
#
# will
# top
#
# support
# reliable
# right
# strong
#
# ...
